# %% [markdown]
# ---
# title: Spotify
# author: Malene_Comeau
# date: 2025-02-14
# categories: [christmas, movie, top] # tags for a blog post (e.g., python)
# image: "holiday-image.png"
#
# toc: true
# ---

# %%
import pandas as pd
# Below is for an interactive display of DataFrame in Colab
from google.colab import data_table
data_table.enable_dataframe_formatter()
holiday_movies = pd.read_csv("https://bcdanl.github.io/data/holiday_movies.csv")
holiday_movies
# Out:
#          tconst title_type             primary_title  \
# 0     tt0020356      movie          Sailor's Holiday
# 1     tt0020823      movie       The Devil's Holiday
# 2     tt0020985      movie                   Holiday
# 3     tt0021268      movie     Holiday of St. Jorgen
# 4     tt0021377      movie       Sin Takes a Holiday
# ...         ...        ...                       ...
# 2260  tt9747440    tvMovie    A Christmas Love Story
# 2261  tt9747450    tvMovie        Holiday for Heroes
# 2262  tt9802890    tvMovie            Christmas Jars
# 2263  tt9815084    tvMovie  A Very British Christmas
# 2264  tt9892854    tvMovie                     #Xmas
#
#                   simple_title  year  runtime_minutes  average_rating  \
# 0              sailors holiday  1929             58.0             5.4
# 1           the devils holiday  1930             80.0             6.0
# 2                      holiday  1930             91.0             6.3
# ...

# %% [markdown]
# Using the provided DataFrames, write a blog post about Christmas movies in a Jupyter Notebook and publish it on your online blog.
#  In your analysis, make use of counting, sorting, indexing, filtering, and joining techniques.

# %%
(
holiday_movies
  [['primary_title', 'year', 'average_rating']]
  .set_index('primary_title')
  .query("year > 2000")
  .value_counts()

)

# I narrowed down the holiday movies to the year I was born, and grew up watching these movies. I found the rating for all of the movies from 2005-2023 as well as the names of all of them.
# Out:
# year  average_rating
# 2021  6.3               15
#       6.5               13
# 2020  5.8               13
# 2022  6.2               12
# 2021  5.5               12
#                         ..
# 2023  8.2                1
#       8.0                1
#       7.6                1
#       7.0                1
# 2001  6.6                1
# Name: count, Length: 770, dtype: int64
